# %%
import os
import cdsapi

# %%
dataset = "projections-cmip6"

output_dir = "/glade/derecho/scratch/skygale/tmp/ssp370/"
os.makedirs(output_dir, exist_ok=True)

models = [
    "access_cm2",
    "awi_cm_1_1_mr",
    "canesm5_canoe",
    "cesm2",
    "cesm2_waccm",
    "cmcc_cm2_sr5",
    "cnrm_cm6_1",
    "cnrm_cm6_1_hr",
    "cnrm_esm2_1",
    "ec_earth3_aerchem",
    "ec_earth3_veg_lr",
    "fgoals_f3_l",
    "fgoals_g3",
    "gfdl_esm4",
    "iitm_esm",
    "inm_cm4_8",
    "inm_cm5_0",
    "ipsl_cm5a2_inca",
    "ipsl_cm6a_lr",
    "kace_1_0_g",
    "mcm_ua_1_0",
    "miroc6",
    "miroc_es2l",
    "mpi_esm1_2_lr",
    "mri_esm2_0",
    "noresm2_mm",
    "taiesm1",
    "ukesm1_0_ll"
]

years = [str(y) for y in range(2015, 2023)]

base_request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp3_7_0",
    "variable": "eastward_wind",
    "level": [
        "1", "5", "10", "20", "30", "50", "70", "100",
        "150", "200", "250", "300", "400", "500", "600",
        "700", "850", "925", "1000"
    ],
    "year": years,
    "month": ["03", "04", "05"],
    "area": [90, -180, 20, 180]
}

client = cdsapi.Client()

for model in models:
    print(f"Downloading model: {model}")
    outfile = os.path.join(
        output_dir,
        f"{model}_2015_2022.zip"
    )
    
    request = base_request.copy()
    request["model"] = model

    client.retrieve(dataset, request).download(outfile)

print("All downloads submitted.")
# Out:
# Downloading model: noresm2_mm
# 2026-07-02 18:30:04,103 INFO Request ID is e1f16709-0f43-4daf-a2ab-9087a8782682
# 2026-07-02 18:30:04,308 INFO status has been updated to accepted
# 2026-07-02 18:30:25,110 INFO status has been updated to running
# 2026-07-02 18:30:54,093 INFO status has been updated to successful
# 274cde67acb84c439dbf2c778223cff8.zip:   0%|          | 0.00/28.8M [00:00<?, ?B/s]
# Downloading model: taiesm1
# 2026-07-02 18:30:59,102 INFO Request ID is ca92f640-3288-49b1-b59d-9effb60376e2
# 2026-07-02 18:30:59,296 INFO status has been updated to accepted
# 2026-07-02 18:31:20,038 INFO status has been updated to running
# 2026-07-02 18:31:31,636 INFO status has been updated to successful
# aa0bb251ca61ef10145b7eb427c7abd1.zip:   0%|          | 0.00/28.4M [00:00<?, ?B/s]
# Downloading model: ukesm1_0_ll
# 2026-07-02 18:31:36,293 INFO Request ID is d9a0f9e5-51f8-437e-8670-98236282805b
# 2026-07-02 18:31:36,466 INFO status has been updated to accepted
# 2026-07-02 18:31:49,408 INFO status has been updated to running
# 2026-07-02 18:32:08,807 INFO status has been updated to successful
# 22107eccfddb0cda45a689f112df5e1b.zip:   0%|          | 0.00/10.7M [00:00<?, ?B/s]
# All downloads submitted.
