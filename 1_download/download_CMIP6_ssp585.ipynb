# %%
import os
import cdsapi

# %%
dataset = "projections-cmip6"

output_dir = "/glade/derecho/scratch/skygale/tmp/ssp585/"
os.makedirs(output_dir, exist_ok=True)

models = [
    "access_cm2",
    "awi_cm_1_1_mr",
    "canesm5_canoe",
    "cesm2",
    "ciesm",
    "cmcc_cm2_sr5",
    "cmcc_esm2",
    "cnrm_cm6_1",
    "cnrm_cm6_1_hr",
    "cnrm_esm2_1",
    "ec_earth3_veg_lr",
    "fgoals_f3_l",
    "fgoals_g3",
    "fio_esm_2_0",
    "gfdl_esm4",
    "hadgem3_gc31_ll",
    "hadgem3_gc31_mm",
    "iitm_esm",
    "inm_cm4_8",
    "inm_cm5_0",
    "ipsl_cm6a_lr",
    "kiost_esm",
    "mcm_ua_1_0",
    "miroc6",
    "miroc_es2l",
    "mpi_esm1_2_lr",
    "nesm3",
    "noresm2_lm",
    "taiesm1",
    "ukesm1_0_ll"
]

years = [str(y) for y in range(2015, 2023)]

base_request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp5_8_5",
    "variable": "air_temperature",
    "level": [
        "1", "5", "10", "20", "30", "50", "70", "100",
        "150", "200", "250", "300", "400", "500", "600",
        "700", "850", "925", "1000"
    ],
    "year": years,
    "month": ["03", "04", "05"],
    "area": [90, -180, 20, 180]
}

client = cdsapi.Client()

for model in models:
    print(f"Downloading model: {model}")
    outfile = os.path.join(
        output_dir,
        f"{model}_2015_2022.zip"
    )

    request = base_request.copy()
    request["model"] = model

    client.retrieve(dataset, request).download(outfile)

print("All downloads submitted.")
# Out:
# Downloading model: access_cm2
# 2026-07-16 11:14:17,098 INFO Request ID is 49d67dbd-c3b1-4206-947d-56260f6e39b9
# 2026-07-16 11:14:17,322 INFO status has been updated to accepted
# 2026-07-16 11:14:49,727 INFO status has been updated to running
# 2026-07-16 11:15:06,998 INFO status has been updated to successful
# dac59378ec6da3a721ba300db18a1b70.zip:   0%|          | 0.00/12.3M [00:00<?, ?B/s]
# Downloading model: awi_cm_1_1_mr
# 2026-07-16 11:15:10,898 INFO Request ID is de9085fd-0a5c-4810-84cd-6d47f230f68c
# 2026-07-16 11:15:11,122 INFO status has been updated to accepted
# 2026-07-16 11:15:29,802 INFO status has been updated to running
# 2026-07-16 11:16:06,404 INFO status has been updated to successful
# fe36bb7b4b2f43880413feeb9ae0ce61.zip:   0%|          | 0.00/38.1M [00:00<?, ?B/s]
# Downloading model: canesm5_canoe
# 2026-07-16 11:16:11,654 INFO Request ID is f7ad2b56-787c-4085-9fb8-839c3fd53925
# 2026-07-16 11:16:11,901 INFO status has been updated to accepted
# 2026-07-16 11:16:32,663 INFO status has been updated to running
# 2026-07-16 11:17:01,489 INFO status has been updated to successful
# 9734c1f4b195b05fe8a2e937ff96fe8e.zip:   0%|          | 0.00/4.76M [00:00<?, ?B/s]
# Downloading model: cesm2
# 2026-07-16 11:17:04,476 INFO Request ID is 4e37eb3e-f372-42bb-8844-2c188cab6fe2
# 2026-07-16 11:17:04,681 INFO status has been updated to accepted
# 2026-07-16 11:17:25,445 INFO status has been updated to running
# 2026-07-16 11:17:56,286 INFO status has been updated to successful
# fc2c07111e97e3eb6b317f23ba5e15a.zip:   0%|          | 0.00/19.9M [00:00<?, ?B/s]
# Downloading model: ciesm
# 2026-07-16 11:18:00,181 INFO Request ID is c9e49b95-f2e9-4abc-b8d8-a369528d0589
# 2026-07-16 11:18:00,331 INFO status has been updated to accepted
# 2026-07-16 11:18:49,732 INFO status has been updated to running
# 2026-07-16 11:19:15,624 INFO status has been updated to successful
# eb9a3382f04a9c81d0bbbe615623bf7b.zip:   0%|          | 0.00/27.5M [00:00<?, ?B/s]
# Downloading model: cmcc_cm2_sr5
# 2026-07-16 11:19:19,983 INFO Request ID is 4d1c3bde-124f-457a-a38d-a1ecb53571ce
# 2026-07-16 11:19:20,875 INFO status has been updated to accepted
# 2026-07-16 11:19:33,882 INFO status has been updated to running
# 2026-07-16 11:20:10,580 INFO status has been updated to successful
# 874fac8daa5e5e0707d2e027a0c2778b.zip:   0%|          | 0.00/20.6M [00:00<?, ?B/s]
# Downloading model: cmcc_esm2
# 2026-07-16 11:20:15,261 INFO Request ID is 8db064ff-2285-4985-9475-63889844da2e
# 2026-07-16 11:20:15,414 INFO status has been updated to accepted
# 2026-07-16 11:20:28,287 INFO status has been updated to running
# 2026-07-16 11:20:47,599 INFO status has been updated to successful
# 8489ca6117c72c278da74773bf2c6327.zip:   0%|          | 0.00/20.6M [00:00<?, ?B/s]
# Downloading model: cnrm_cm6_1
# 2026-07-16 11:20:53,340 INFO Request ID is 5d542c6d-1e44-4708-b3ac-e451fb19e674
# 2026-07-16 11:20:53,488 INFO status has been updated to accepted
# 2026-07-16 11:21:14,075 INFO status has been updated to running
# 2026-07-16 11:21:25,642 INFO status has been updated to successful
# 672dbf7230b6ea5d1186fd01fbc643e4.zip:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# Downloading model: cnrm_cm6_1_hr
# 2026-07-16 11:21:29,790 INFO Request ID is 7558f6c5-8cc4-47b0-87ff-34eaeb96e56f
# 2026-07-16 11:21:29,955 INFO status has been updated to accepted
# 2026-07-16 11:21:42,975 INFO status has been updated to running
# 2026-07-16 11:22:19,582 INFO status has been updated to successful
# b7c091d10895960d6162447aead23cfb.zip:   0%|          | 0.00/81.2M [00:00<?, ?B/s]
# Downloading model: cnrm_esm2_1
# 2026-07-16 11:22:26,345 INFO Request ID is 4f8a7696-6e3e-45ab-8466-3ef47eea04c3
# 2026-07-16 11:22:26,499 INFO status has been updated to accepted
# 2026-07-16 11:22:40,568 INFO status has been updated to running
# 2026-07-16 11:23:01,523 INFO status has been updated to successful
# 46b87e67dce75ce8b2e587318ae059e3.zip:   0%|          | 0.00/11.9M [00:00<?, ?B/s]
# Downloading model: ec_earth3_veg_lr
# 2026-07-16 11:23:07,082 INFO Request ID is 685112fd-2b7c-42b2-89b2-8d13e8d59f6d
# 2026-07-16 11:23:08,336 INFO status has been updated to accepted
# 2026-07-16 11:23:40,465 INFO status has been updated to running
# 2026-07-16 11:24:26,412 INFO status has been updated to successful
# acb7779d5f6d979c421eae3d366ac015.zip:   0%|          | 0.00/26.8M [00:00<?, ?B/s]
# Downloading model: fgoals_f3_l
# 2026-07-16 11:24:30,367 INFO Request ID is 42462428-1907-4f64-95d4-5d2e439bf4db
# 2026-07-16 11:24:30,523 INFO status has been updated to accepted
# 2026-07-16 11:24:51,209 INFO status has been updated to running
# 2026-07-16 11:25:20,002 INFO status has been updated to successful
# 6bc0bbeb183e394f4e5af31ffd9e7fb9.zip:   0%|          | 0.00/40.2M [00:00<?, ?B/s]
# Downloading model: fgoals_g3
# 2026-07-16 11:25:26,068 INFO Request ID is f255c9e1-6ce3-4a6f-be64-23bcf148c5b1
# 2026-07-16 11:25:26,219 INFO status has been updated to accepted
# 2026-07-16 11:25:46,802 INFO status has been updated to running
# 2026-07-16 11:26:15,656 INFO status has been updated to successful
# d3ea8175f8de8c9eca06b5c24291c668.zip:   0%|          | 0.00/9.68M [00:00<?, ?B/s]
# Downloading model: fio_esm_2_0
# 2026-07-16 11:26:19,308 INFO Request ID is 2ddca8e5-61d2-455c-b116-68840ba765e3
# 2026-07-16 11:26:19,463 INFO status has been updated to accepted
# 2026-07-16 11:26:40,041 INFO status has been updated to running
# 2026-07-16 11:26:51,619 INFO status has been updated to successful
# 37fb8b728840c354fb26a63ccbac9c7d.zip:   0%|          | 0.00/28.5M [00:00<?, ?B/s]
# Downloading model: gfdl_esm4
# 2026-07-16 11:26:55,954 INFO Request ID is 12fa34b9-14ea-4963-9cbd-09b07f6cabed
# 2026-07-16 11:26:56,105 INFO status has been updated to accepted
# 2026-07-16 11:27:08,943 INFO status has been updated to running
# 2026-07-16 11:27:29,836 INFO status has been updated to successful
# 2566502ade0949b029c4fdffd812bf6a.zip:   0%|          | 0.00/19.0M [00:00<?, ?B/s]
# Downloading model: hadgem3_gc31_ll
# 2026-07-16 11:27:35,822 INFO Request ID is 065d592d-0e33-4780-aa0e-fbfa086dbd1a
# 2026-07-16 11:27:35,981 INFO status has been updated to accepted
# 2026-07-16 11:27:56,554 INFO status has been updated to running
# 2026-07-16 11:28:08,108 INFO status has been updated to successful
# f3bc52e903bbf96884c6c635c96d4e93.zip:   0%|          | 0.00/9.46M [00:00<?, ?B/s]
# Downloading model: hadgem3_gc31_mm
# 2026-07-16 11:28:11,616 INFO Request ID is 6632b6a5-27ea-4602-bb65-d483a2f33eb5
# 2026-07-16 11:28:11,774 INFO status has been updated to accepted
# 2026-07-16 11:28:32,364 INFO status has been updated to running
# 2026-07-16 11:29:03,679 INFO status has been updated to successful
# d9388c0fc55379997344a5a873243886.zip:   0%|          | 0.00/42.3M [00:00<?, ?B/s]
# Downloading model: iitm_esm
# 2026-07-16 11:29:08,370 INFO Request ID is ec4ef574-8f6a-403f-84a4-ac757a69fd45
# 2026-07-16 11:29:08,521 INFO status has been updated to accepted
# 2026-07-16 11:29:29,126 INFO status has been updated to running
# 2026-07-16 11:29:40,706 INFO status has been updated to successful
# 9b06a8479fd034914cfe4ed00964cc6f.zip:   0%|          | 0.00/9.72M [00:00<?, ?B/s]
# Downloading model: inm_cm4_8
# 2026-07-16 11:29:44,140 INFO Request ID is f9d89d29-4284-4048-bea5-276824a17255
# 2026-07-16 11:29:44,295 INFO status has been updated to accepted
# 2026-07-16 11:29:57,135 INFO status has been updated to running
# 2026-07-16 11:30:16,448 INFO status has been updated to successful
# b191be7e460ec92a4b275fd84368c5dc.zip:   0%|          | 0.00/7.72M [00:00<?, ?B/s]
# Downloading model: inm_cm5_0
# 2026-07-16 11:30:20,570 INFO Request ID is 3b032345-2a92-4c0a-9b7e-074fd655d3b5
# 2026-07-16 11:30:20,728 INFO status has been updated to accepted
# 2026-07-16 11:30:52,904 INFO status has been updated to running
# 2026-07-16 11:31:10,170 INFO status has been updated to successful
# c24f0f68c88433379d8986f7779f9953.zip:   0%|          | 0.00/11.7M [00:00<?, ?B/s]
# Downloading model: ipsl_cm6a_lr
# 2026-07-16 11:31:13,612 INFO Request ID is 3ebd6253-4077-4e37-a2e4-62c02ff34673
# 2026-07-16 11:31:15,810 INFO status has been updated to accepted
# 2026-07-16 11:31:36,446 INFO status has been updated to running
# 2026-07-16 11:32:05,302 INFO status has been updated to successful
# a5c03553fd6c4de9bef132b03d9a10bf.zip:   0%|          | 0.00/8.19M [00:00<?, ?B/s]
# Downloading model: kiost_esm
# 2026-07-16 11:32:08,555 INFO Request ID is d564dfb4-f427-4e65-9603-8ca43126dd65
# 2026-07-16 11:32:09,906 INFO status has been updated to accepted
# 2026-07-16 11:32:24,747 INFO status has been updated to running
# 2026-07-16 11:32:44,082 INFO status has been updated to successful
# fbbb21776d49a78127cc6f75fa8c460b.zip:   0%|          | 0.00/14.3M [00:00<?, ?B/s]
# Downloading model: mcm_ua_1_0
# 2026-07-16 11:32:47,578 INFO Request ID is bb4192e8-e1d9-49e4-ac0c-ce17679b783a
# 2026-07-16 11:32:47,740 INFO status has been updated to accepted
# 2026-07-16 11:33:00,565 INFO status has been updated to running
# 2026-07-16 11:33:19,904 INFO status has been updated to accepted
# 2026-07-16 11:33:37,186 INFO status has been updated to running
# 2026-07-16 11:34:04,633 INFO status has been updated to successful
# 40d48da6831e784295c90cd0bc5f62ec.zip:   0%|          | 0.00/5.89M [00:00<?, ?B/s]
# Downloading model: miroc6
# 2026-07-16 11:34:07,855 INFO Request ID is 8559341f-1947-42f8-b226-60f1bbab32a3
# 2026-07-16 11:34:08,008 INFO status has been updated to accepted
# 2026-07-16 11:34:29,237 INFO status has been updated to running
# 2026-07-16 11:34:58,113 INFO status has been updated to successful
# c7c351dfb6f3e717e0a708556a23f716.zip:   0%|          | 0.00/12.4M [00:00<?, ?B/s]
# Downloading model: miroc_es2l
# 2026-07-16 11:35:03,569 INFO Request ID is 981c3206-423e-42fb-a980-0423070b1cd3
# 2026-07-16 11:35:03,734 INFO status has been updated to accepted
# 2026-07-16 11:35:24,705 INFO status has been updated to running
# 2026-07-16 11:35:53,572 INFO status has been updated to successful
# 347f4f200f587566c3811183d42f6103.zip:   0%|          | 0.00/3.53M [00:00<?, ?B/s]
# Downloading model: mpi_esm1_2_lr
# 2026-07-16 11:35:56,681 INFO Request ID is 87c578e8-b319-4eb1-aa7f-4ae47a2297f8
# 2026-07-16 11:35:56,832 INFO status has been updated to accepted
# 2026-07-16 11:36:17,695 INFO status has been updated to running
# 2026-07-16 11:36:47,035 INFO status has been updated to successful
# fafd7ed5deebadf39344e18502dbb0f0.zip:   0%|          | 0.00/6.17M [00:00<?, ?B/s]
# Downloading model: nesm3
# 2026-07-16 11:36:50,383 INFO Request ID is 4e4feaac-6728-4ca7-af4b-d5396841a868
# 2026-07-16 11:36:50,538 INFO status has been updated to accepted
# 2026-07-16 11:37:03,679 INFO status has been updated to running
# 2026-07-16 11:37:23,030 INFO status has been updated to successful
# 6f1bee0c701ad6b554d2b954164dca8b.zip:   0%|          | 0.00/10.0M [00:00<?, ?B/s]
# Downloading model: noresm2_lm
# 2026-07-16 11:37:26,641 INFO Request ID is a7ca397c-b1c0-4ec9-b955-c4d37ce9bd00
# 2026-07-16 11:37:27,864 INFO status has been updated to accepted
# 2026-07-16 11:37:48,475 INFO status has been updated to running
# 2026-07-16 11:38:00,033 INFO status has been updated to successful
# a90cbf5bc3501776f3177e683dfcd623.zip:   0%|          | 0.00/5.50M [00:00<?, ?B/s]
# Downloading model: taiesm1
# 2026-07-16 11:38:03,782 INFO Request ID is 59df677d-99e1-494a-af95-233c1241163e
# 2026-07-16 11:38:03,935 INFO status has been updated to accepted
# 2026-07-16 11:38:24,845 INFO status has been updated to running
# 2026-07-16 11:38:57,395 INFO status has been updated to successful
# 17177c838e3acaec2b6bbb3ae13e8fb3.zip:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# Downloading model: ukesm1_0_ll
# 2026-07-16 11:39:03,377 INFO Request ID is 2068c673-f543-450d-ae3c-7884da139315
# 2026-07-16 11:39:04,474 INFO status has been updated to accepted
# 2026-07-16 11:39:17,282 INFO status has been updated to running
