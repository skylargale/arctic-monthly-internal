# %%
import os
import cdsapi

# %%
dataset = "projections-cmip6"

output_dir = "/glade/derecho/scratch/skygale/tmp/historical/"
os.makedirs(output_dir, exist_ok=True)

models = [
    # "access_cm2",
    # "access_esm1_5",
    # "awi_cm_1_1_mr",
    # "awi_esm_1_1_lr",
    # "bcc_esm1",
    # "canesm5_canoe",
    # "cesm2",
    # "cesm2_fv2",
    # "cesm2_waccm",
    # "cesm2_waccm_fv2",
    # "ciesm",
    # "cmcc_cm2_hr4",
    # "cmcc_cm2_sr5",
    # "cmcc_esm2",
    # "cnrm_cm6_1",
    # "cnrm_esm2_1",
    "ec_earth3_aerchem",
    "ec_earth3_cc",
    "ec_earth3_veg_lr",
    "fgoals_f3_l",
    "fgoals_g3",
    "fio_esm_2_0",
    "gfdl_esm4",
    "giss_e2_1_h",
    "hadgem3_gc31_ll",
    "hadgem3_gc31_mm",
    "iitm_esm",
    "inm_cm4_8",
    "inm_cm5_0",
    "ipsl_cm5a2_inca",
    "ipsl_cm6a_lr",
    "kace_1_0_g",
    "kiost_esm",
    "mcm_ua_1_0",
    "miroc6",
    "miroc_es2h",
    "miroc_es2l",
    "mpi_esm1_2_hr",
    "mpi_esm1_2_lr",
    "mri_esm2_0",
    "nesm3",
    "norcpm1",
    "noresm2_mm",
    "sam0_unicon",
    "taiesm1",
    "ukesm1_0_ll"
]

years = [str(y) for y in range(1980, 2015)]

base_request = {
    "temporal_resolution": "monthly",
    "experiment": "historical",
    "variable": "eastward_wind",
    "level": [
        "1", "5", "10", "20", "30", "50", "70", "100",
        "150", "200", "250", "300", "400", "500", "600",
        "700", "850", "925", "1000"
    ],
    "year": years,
    "month": ["03", "04", "05"],
    "area": [90, -180, 20, 180]
}

client = cdsapi.Client()

for model in models:
    print(f"Downloading model: {model}")
    outfile = os.path.join(
        output_dir,
        f"{model}_1980_2014.zip"
    )
    
    request = base_request.copy()
    request["model"] = model

    client.retrieve(dataset, request).download(outfile)

print("All downloads submitted.")
# Out:
# Downloading model: ec_earth3_aerchem
# 2026-07-02 17:03:40,568 INFO Request ID is 3c46c258-f3ab-4f22-a8a9-dae56755ad53
# 2026-07-02 17:03:40,767 INFO status has been updated to accepted
# 2026-07-02 17:04:01,544 INFO status has been updated to running
# 2026-07-02 17:05:34,990 INFO status has been updated to successful
# 90c701cd5393d7e5d53e058ec5d6511b.zip:   0%|          | 0.00/352M [00:00<?, ?B/s]
# Downloading model: ec_earth3_cc
# 2026-07-02 17:05:57,284 INFO Request ID is 658b4a93-21e2-4227-86de-7b25870b14d5
# 2026-07-02 17:05:57,480 INFO status has been updated to accepted
# 2026-07-02 17:06:10,556 INFO status has been updated to running
# 2026-07-02 17:07:52,389 INFO status has been updated to successful
# 8c9806467826ce95dc045bf1012a6840.zip:   0%|          | 0.00/352M [00:00<?, ?B/s]
# Downloading model: ec_earth3_veg_lr
# 2026-07-02 17:08:14,723 INFO Request ID is 05c9db0d-3f4a-4d03-b685-5e0c7f167d30
# 2026-07-02 17:08:14,944 INFO status has been updated to accepted
# 2026-07-02 17:08:37,218 INFO status has been updated to running
# 2026-07-02 17:10:11,531 INFO status has been updated to successful
# 776327d74afaaaa264d8e072c0bddea.zip:   0%|          | 0.00/139M [00:00<?, ?B/s]
# Downloading model: fgoals_f3_l
# 2026-07-02 17:10:23,486 INFO Request ID is b7c80cfb-4849-4cf5-87a0-38c621013267
# 2026-07-02 17:10:23,685 INFO status has been updated to accepted
# 2026-07-02 17:10:44,563 INFO status has been updated to running
# 2026-07-02 17:11:42,127 INFO status has been updated to successful
# 9bde3caa3116046c897a01ef68a03e0d.zip:   0%|          | 0.00/154M [00:00<?, ?B/s]
# Downloading model: fgoals_g3
# 2026-07-02 17:11:55,255 INFO Request ID is 2f3b9a01-e478-479f-bdac-482b91dfc287
# 2026-07-02 17:11:55,628 INFO status has been updated to accepted
# 2026-07-02 17:12:16,507 INFO status has been updated to running
# 2026-07-02 17:12:47,420 INFO status has been updated to successful
# 1adeed7cfa317199e40fb88618e4bf27.zip:   0%|          | 0.00/41.7M [00:00<?, ?B/s]
# Downloading model: fio_esm_2_0
# 2026-07-02 17:12:53,270 INFO Request ID is 89cf76bb-dcad-4bde-aa4e-653adb1621cb
# 2026-07-02 17:12:53,468 INFO status has been updated to accepted
# 2026-07-02 17:13:14,247 INFO status has been updated to running
# 2026-07-02 17:14:08,999 INFO status has been updated to successful
# 4baa9b17cce3c506585ef3a9d2450eb1.zip:   0%|          | 0.00/150M [00:00<?, ?B/s]
# Downloading model: gfdl_esm4
# 2026-07-02 17:14:22,814 INFO Request ID is c860ef8f-9b35-4f8a-b4f3-06c8720b04df
# 2026-07-02 17:14:23,015 INFO status has been updated to accepted
# 2026-07-02 17:14:45,056 INFO status has been updated to running
# 2026-07-02 17:15:13,995 INFO status has been updated to successful
# 91c562a2a1c58e440787edf8fef89ab2.zip:   0%|          | 0.00/114M [00:00<?, ?B/s]
# Downloading model: giss_e2_1_h
# 2026-07-02 17:15:25,688 INFO Request ID is ffb1abd9-dda3-472e-ba68-8696ce7e40b7
# 2026-07-02 17:15:25,889 INFO status has been updated to accepted
# 2026-07-02 17:15:47,152 INFO status has been updated to running
# 2026-07-02 17:16:16,140 INFO status has been updated to successful
# 713c73eff23d3107e8ec0ea0f8690022.zip:   0%|          | 0.00/38.9M [00:00<?, ?B/s]
# Downloading model: hadgem3_gc31_ll
# 2026-07-02 17:16:21,529 INFO Request ID is fa0130c7-46ff-4222-a5ae-64c24c724d74
# 2026-07-02 17:16:22,066 INFO status has been updated to accepted
# 2026-07-02 17:16:42,817 INFO status has been updated to running
# 2026-07-02 17:17:11,711 INFO status has been updated to successful
# 4ab11ba5a60e0114621fc38e82e5cf7.zip:   0%|          | 0.00/45.6M [00:00<?, ?B/s]
# Downloading model: hadgem3_gc31_mm
# 2026-07-02 17:17:17,592 INFO Request ID is 1b7bf83c-4c4c-46e9-b135-5d54ad7656f8
# 2026-07-02 17:17:17,772 INFO status has been updated to accepted
# 2026-07-02 17:17:50,250 INFO status has been updated to running
# 2026-07-02 17:19:12,628 INFO status has been updated to successful
# aa8479d3e627041af3a42c0f25340443.zip:   0%|          | 0.00/202M [00:00<?, ?B/s]
# Downloading model: iitm_esm
# 2026-07-02 17:19:26,260 INFO Request ID is 03e91975-2599-44be-8c75-d42d748dbb06
# 2026-07-02 17:19:26,460 INFO status has been updated to accepted
# 2026-07-02 17:19:40,035 INFO status has been updated to running
# 2026-07-02 17:20:17,156 INFO status has been updated to successful
# 2aa6425e2cb17bdf20c11d3f9851b3f2.zip:   0%|          | 0.00/48.4M [00:00<?, ?B/s]
# Downloading model: inm_cm4_8
# 2026-07-02 17:20:23,359 INFO Request ID is 643cd36d-58d8-49f9-8138-47d69fba825b
# 2026-07-02 17:20:23,561 INFO status has been updated to accepted
# 2026-07-02 17:20:46,272 INFO status has been updated to running
# 2026-07-02 17:21:15,169 INFO status has been updated to successful
# 9702b59bee7ebbb730b0abe6b13655cd.zip:   0%|          | 0.00/45.1M [00:00<?, ?B/s]
# Downloading model: inm_cm5_0
# 2026-07-02 17:21:20,716 INFO Request ID is 04fc22b3-89c8-4ee5-a3df-f338ab6c5152
# 2026-07-02 17:21:20,904 INFO status has been updated to accepted
# 2026-07-02 17:21:42,558 INFO status has been updated to running
# 2026-07-02 17:22:11,454 INFO status has been updated to successful
# 1d1a54955931343f14013a849777da4f.zip:   0%|          | 0.00/50.3M [00:00<?, ?B/s]
# Downloading model: ipsl_cm5a2_inca
# 2026-07-02 17:22:17,945 INFO Request ID is 0d12e6e3-f525-4181-b809-c38961d58e85
# 2026-07-02 17:22:18,176 INFO status has been updated to accepted
# 2026-07-02 17:22:39,001 INFO status has been updated to running
# 2026-07-02 17:23:08,648 INFO status has been updated to successful
# 1a921d2cc9a3677acec71c0f5a0af3a7.zip:   0%|          | 0.00/21.3M [00:00<?, ?B/s]
# Downloading model: ipsl_cm6a_lr
# 2026-07-02 17:23:13,050 INFO Request ID is c4c3809f-acf5-4d6b-b215-7bf53d0700ff
# 2026-07-02 17:23:13,231 INFO status has been updated to accepted
# 2026-07-02 17:23:26,164 INFO status has been updated to running
# 2026-07-02 17:24:02,845 INFO status has been updated to successful
# a01561c9a5765584cde11bfb591febbd.zip:   0%|          | 0.00/46.9M [00:00<?, ?B/s]
# Downloading model: kace_1_0_g
# 2026-07-02 17:24:09,150 INFO Request ID is fcb6a4e1-3e40-4a83-bd88-e0e08f76e86d
# 2026-07-02 17:24:09,331 INFO status has been updated to accepted
# 2026-07-02 17:24:23,151 INFO status has been updated to running
# 2026-07-02 17:24:59,803 INFO status has been updated to successful
# 1be0b068edf683e43e9e7cbc83a9df78.zip:   0%|          | 0.00/45.6M [00:00<?, ?B/s]
# Downloading model: kiost_esm
# 2026-07-02 17:25:06,072 INFO Request ID is c4a3c38a-3828-4858-91ad-f19928e4f9cf
# 2026-07-02 17:25:06,287 INFO status has been updated to accepted
# 2026-07-02 17:25:28,420 INFO status has been updated to running
# 2026-07-02 17:25:40,012 INFO status has been updated to successful
# ddc85f3b9a2d0599c55469fb8b414f8e.zip:   0%|          | 0.00/69.2M [00:00<?, ?B/s]
# Downloading model: mcm_ua_1_0
# 2026-07-02 17:25:48,066 INFO Request ID is 5cdb47d1-6dc2-47ab-84db-43d8188e8b3a
# 2026-07-02 17:25:48,359 INFO status has been updated to accepted
# 2026-07-02 17:26:20,820 INFO status has been updated to running
# 2026-07-02 17:27:42,618 INFO status has been updated to successful
# efe68a6e434ecfe4952f413d85d33b4c.zip:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# Downloading model: miroc6
# 2026-07-02 17:27:48,134 INFO Request ID is 33c814a2-4f66-499b-bcc2-4003858a96de
# 2026-07-02 17:27:48,329 INFO status has been updated to accepted
# 2026-07-02 17:28:09,069 INFO status has been updated to running
# 2026-07-02 17:28:37,983 INFO status has been updated to successful
# 1914273f840eee1fc6f2587b52a36ad4.zip:   0%|          | 0.00/73.6M [00:00<?, ?B/s]
# Downloading model: miroc_es2h
# 2026-07-02 17:28:46,294 INFO Request ID is 683dca2c-9e5e-48a2-a16b-039947b39c99
# 2026-07-02 17:28:46,471 INFO status has been updated to accepted
# 2026-07-02 17:29:07,515 INFO status has been updated to running
# 2026-07-02 17:30:02,252 INFO status has been updated to successful
# ac0e87b7c1373ba586fd4d691401a5e7.zip:   0%|          | 0.00/73.1M [00:00<?, ?B/s]
# Downloading model: miroc_es2l
# 2026-07-02 17:30:10,392 INFO Request ID is 82f43001-00a1-4e8e-89aa-550c9aa078b9
# 2026-07-02 17:30:10,601 INFO status has been updated to accepted
# 2026-07-02 17:30:23,732 INFO status has been updated to running
# 2026-07-02 17:30:43,083 INFO status has been updated to successful
# 38e06f9116834606f746d069d872ebd5.zip:   0%|          | 0.00/19.3M [00:00<?, ?B/s]
# Downloading model: mpi_esm1_2_hr
# Recovering from HTTP error [502 Bad Gateway], attemps 1 of 500
# Retrying in 120 seconds
# 2026-07-02 17:32:49,446 INFO Request ID is 5edc5b09-8370-44f7-aace-2ae6272e2312
# 2026-07-02 17:32:49,655 INFO status has been updated to accepted
# 2026-07-02 17:33:10,935 INFO status has been updated to running
# 2026-07-02 17:34:05,921 INFO status has been updated to successful
# 21ef5baf0c957e96d68987672fbfd73a.zip:   0%|          | 0.00/113M [00:00<?, ?B/s]
# Downloading model: mpi_esm1_2_lr
# 2026-07-02 17:34:14,992 INFO Request ID is b581c5b3-84ca-49b5-aab7-11509fc83210
# 2026-07-02 17:34:15,181 INFO status has been updated to accepted
# 2026-07-02 17:34:28,143 INFO status has been updated to running
# 2026-07-02 17:34:47,723 INFO status has been updated to successful
# 3cbf39c1b932914a276781aaae69bfef.zip:   0%|          | 0.00/31.4M [00:00<?, ?B/s]
# Downloading model: mri_esm2_0
# 2026-07-02 17:34:52,689 INFO Request ID is 45eed228-9bd5-4b81-af48-431ac8b8501a
# 2026-07-02 17:34:53,076 INFO status has been updated to accepted
# 2026-07-02 17:35:13,867 INFO status has been updated to running
# 2026-07-02 17:35:42,743 INFO status has been updated to successful
# 22d787c0e34bbe0a6364b67a969d19e1.zip:   0%|          | 0.00/110M [00:00<?, ?B/s]
# Downloading model: nesm3
# 2026-07-02 17:35:52,048 INFO Request ID is ec253758-a1ae-4905-9a96-ca4fac8eb405
# 2026-07-02 17:35:52,939 INFO status has been updated to accepted
# 2026-07-02 17:36:13,779 INFO status has been updated to running
# 2026-07-02 17:36:42,662 INFO status has been updated to successful
# 1bc14ad26e8f30924935615f22436d38.zip:   0%|          | 0.00/49.5M [00:00<?, ?B/s]
# Downloading model: norcpm1
# 2026-07-02 17:36:49,440 INFO Request ID is ff50674a-7c46-4b98-9f3a-c8e4926a3434
# 2026-07-02 17:36:49,627 INFO status has been updated to accepted
# 2026-07-02 17:37:11,629 INFO status has been updated to running
# 2026-07-02 17:37:40,894 INFO status has been updated to successful
# 9e22a33ebe0ada83d36460e1adebf6e4.zip:   0%|          | 0.00/32.0M [00:00<?, ?B/s]
# Downloading model: noresm2_mm
# 2026-07-02 17:37:46,911 INFO Request ID is ce033d23-feb3-4717-a972-434b668f237c
# 2026-07-02 17:37:47,099 INFO status has been updated to accepted
# 2026-07-02 17:38:19,482 INFO status has been updated to running
# 2026-07-02 17:38:36,760 INFO status has been updated to successful
# 30393c2ad8bd10c1a9852f5e098c2e2e.zip:   0%|          | 0.00/124M [00:00<?, ?B/s]
# Downloading model: sam0_unicon
# 2026-07-02 17:38:47,400 INFO Request ID is fbc3ad53-d728-48fc-aee0-1c20b8198f3e
# 2026-07-02 17:38:47,601 INFO status has been updated to accepted
# 2026-07-02 17:39:08,365 INFO status has been updated to running
# 2026-07-02 17:40:03,125 INFO status has been updated to successful
# 8bbcd20e30762b3fdcd48af356374735.zip:   0%|          | 0.00/146M [00:00<?, ?B/s]
# Downloading model: taiesm1
# 2026-07-02 17:40:14,441 INFO Request ID is 5f8298ba-0dd6-4af9-8896-e00c4cf4ff3e
# 2026-07-02 17:40:14,646 INFO status has been updated to accepted
# 2026-07-02 17:40:36,203 INFO status has been updated to running
# 2026-07-02 17:41:31,011 INFO status has been updated to successful
# b8166f87a67bf0a0f4c03ff19c96ce3c.zip:   0%|          | 0.00/124M [00:00<?, ?B/s]
# Downloading model: ukesm1_0_ll
# 2026-07-02 17:41:42,399 INFO Request ID is d5e6e280-b580-470a-9ae6-42d3e23bd3c6
# 2026-07-02 17:41:42,612 INFO status has been updated to accepted
# 2026-07-02 17:41:55,538 INFO status has been updated to running
# 2026-07-02 17:42:32,222 INFO status has been updated to successful
# 2d08a13017c4b64786fe1660d8b3785e.zip:   0%|          | 0.00/45.6M [00:00<?, ?B/s]
# All downloads submitted.
