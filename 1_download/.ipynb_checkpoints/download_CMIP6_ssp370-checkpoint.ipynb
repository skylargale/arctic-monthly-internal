# %%
import os
import cdsapi

# %%
dataset = "projections-cmip6"

output_dir = "/glade/derecho/scratch/skygale/tmp/ssp370/"
os.makedirs(output_dir, exist_ok=True)

models = [
    "access_cm2",
    "awi_cm_1_1_mr",
    "canesm5_canoe",
    "cesm2",
    "cesm2_waccm",
    "cmcc_cm2_sr5",
    "cnrm_cm6_1",
    "cnrm_cm6_1_hr",
    "cnrm_esm2_1",
    "ec_earth3_aerchem",
    "ec_earth3_veg_lr",
    "fgoals_f3_l",
    "fgoals_g3",
    "gfdl_esm4",
    "iitm_esm",
    "inm_cm4_8",
    "inm_cm5_0",
    "ipsl_cm5a2_inca",
    "ipsl_cm6a_lr",
    "kace_1_0_g",
    "mcm_ua_1_0",
    "miroc6",
    "miroc_es2l",
    "mpi_esm1_2_lr",
    "mri_esm2_0",
    "noresm2_mm",
    "taiesm1",
    "ukesm1_0_ll"
]

years = [str(y) for y in range(2015, 2023)]

base_request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp3_7_0",
    "variable": "air_temperature",
    "level": [
        "1", "5", "10", "20", "30", "50", "70", "100",
        "150", "200", "250", "300", "400", "500", "600",
        "700", "850", "925", "1000"
    ],
    "year": years,
    "month": ["03", "04", "05"],
    "area": [90, -180, 20, 180]
}

client = cdsapi.Client()

for model in models:
    print(f"Downloading model: {model}")
    outfile = os.path.join(
        output_dir,
        f"{model}_2015_2022.zip"
    )

    request = base_request.copy()
    request["model"] = model

    client.retrieve(dataset, request).download(outfile)

print("All downloads submitted.")
# Out:
# Downloading model: access_cm2
# 2026-07-16 11:14:09,136 INFO Request ID is 5412b815-7ef9-4a38-9ba4-fe911233e152
# 2026-07-16 11:14:09,316 INFO status has been updated to accepted
# 2026-07-16 11:14:29,915 INFO status has been updated to running
# 2026-07-16 11:14:58,742 INFO status has been updated to successful
# c2c32424c754597bb286ea62d74d9e24.zip:   0%|          | 0.00/12.3M [00:00<?, ?B/s]
# Downloading model: awi_cm_1_1_mr
# 2026-07-16 11:15:02,300 INFO Request ID is aed2df7b-5aa3-4b3a-8212-cf99cfd0a502
# 2026-07-16 11:15:02,448 INFO status has been updated to accepted
# 2026-07-16 11:15:23,264 INFO status has been updated to running
# 2026-07-16 11:15:52,121 INFO status has been updated to successful
# adbe2a543e35ef2afcd3d725cec54828.zip:   0%|          | 0.00/38.2M [00:00<?, ?B/s]
# Downloading model: canesm5_canoe
# 2026-07-16 11:15:59,073 INFO Request ID is 458798e8-6f2e-4371-a10d-9c8cdd3aa5af
# 2026-07-16 11:15:59,502 INFO status has been updated to accepted
# 2026-07-16 11:16:12,606 INFO status has been updated to running
# 2026-07-16 11:16:49,162 INFO status has been updated to successful
# 87ddd891c7386d60dc75868d355552c8.zip:   0%|          | 0.00/4.76M [00:00<?, ?B/s]
# Downloading model: cesm2
# 2026-07-16 11:16:52,237 INFO Request ID is 3fb32fef-18d5-47ff-8c2a-25b7b53d7ced
# 2026-07-16 11:16:52,983 INFO status has been updated to accepted
# 2026-07-16 11:17:06,628 INFO status has been updated to running
# 2026-07-16 11:17:43,198 INFO status has been updated to successful
# f23164d999155ccd5499af1ceb6705ef.zip:   0%|          | 0.00/19.8M [00:00<?, ?B/s]
# Downloading model: cesm2_waccm
# 2026-07-16 11:17:48,493 INFO Request ID is 4e118108-7f8b-4c71-ae97-97f5c7c5c680
# 2026-07-16 11:17:48,640 INFO status has been updated to accepted
# 2026-07-16 11:19:03,938 INFO status has been updated to successful
# 8122cd578b95711dedb8f02663d566a6.zip:   0%|          | 0.00/20.0M [00:00<?, ?B/s]
# Downloading model: cmcc_cm2_sr5
# 2026-07-16 11:19:08,434 INFO Request ID is 4dd269c0-bdce-4233-84ae-4640b4b0834d
# 2026-07-16 11:19:08,609 INFO status has been updated to accepted
# 2026-07-16 11:19:21,444 INFO status has been updated to running
# 2026-07-16 11:19:40,754 INFO status has been updated to successful
# 58791edbc1f6515b3b49468c20499a2f.zip:   0%|          | 0.00/20.6M [00:00<?, ?B/s]
# Downloading model: cnrm_cm6_1
# 2026-07-16 11:19:44,498 INFO Request ID is f0a462f8-0f05-43d4-89b6-cdd8f85e501c
# 2026-07-16 11:19:44,648 INFO status has been updated to accepted
# 2026-07-16 11:19:57,738 INFO status has been updated to running
# 2026-07-16 11:20:18,455 INFO status has been updated to successful
# e22d8507f520b3917617e940dcc22867.zip:   0%|          | 0.00/11.9M [00:00<?, ?B/s]
# Downloading model: cnrm_cm6_1_hr
# 2026-07-16 11:20:21,609 INFO Request ID is 170b34ae-09d3-46d3-9fb5-6bb5268c5e1a
# 2026-07-16 11:20:21,769 INFO status has been updated to accepted
# 2026-07-16 11:20:42,343 INFO status has been updated to running
# 2026-07-16 11:21:11,148 INFO status has been updated to successful
# 7d05b56a8c063528df11122ee9ffd184.zip:   0%|          | 0.00/81.2M [00:00<?, ?B/s]
# Downloading model: cnrm_esm2_1
# 2026-07-16 11:21:18,889 INFO Request ID is c5173064-7f32-4e08-9f6a-813919868e36
# 2026-07-16 11:21:19,443 INFO status has been updated to accepted
# 2026-07-16 11:21:32,273 INFO status has been updated to running
# 2026-07-16 11:21:51,641 INFO status has been updated to successful
# 5855179bba6ef163cec1ac4ac6665cc5.zip:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# Downloading model: ec_earth3_aerchem
# 2026-07-16 11:21:55,150 INFO Request ID is 94676d05-0be5-45ef-a471-42bc813ea737
# 2026-07-16 11:21:55,299 INFO status has been updated to accepted
# 2026-07-16 11:22:09,439 INFO status has been updated to running
# 2026-07-16 11:22:46,018 INFO status has been updated to successful
# f3de21d703a2017f41a4001655d30945.zip:   0%|          | 0.00/65.4M [00:00<?, ?B/s]
# Downloading model: ec_earth3_veg_lr
# 2026-07-16 11:22:53,760 INFO Request ID is 5eb73f3d-51ae-4513-9110-6e20dc29a9e8
# 2026-07-16 11:22:53,914 INFO status has been updated to accepted
# 2026-07-16 11:23:43,336 INFO status has been updated to running
# 2026-07-16 11:24:09,143 INFO status has been updated to successful
# 74091088ee386d83a217f091bbeba342.zip:   0%|          | 0.00/26.8M [00:00<?, ?B/s]
# Downloading model: fgoals_f3_l
# 2026-07-16 11:24:20,040 INFO Request ID is 378795a1-518e-43a5-95ba-91a17a7ecf31
# 2026-07-16 11:24:20,196 INFO status has been updated to accepted
# 2026-07-16 11:24:44,929 INFO status has been updated to running
# 2026-07-16 11:25:13,753 INFO status has been updated to successful
# c6ca46e44c7fc5cbe4cd6b0bac752972.zip:   0%|          | 0.00/40.2M [00:00<?, ?B/s]
# Downloading model: fgoals_g3
# 2026-07-16 11:25:19,392 INFO Request ID is 5ee1f6e5-6ebc-4434-84a1-02537e15b76d
# 2026-07-16 11:25:19,538 INFO status has been updated to accepted
# 2026-07-16 11:25:51,820 INFO status has been updated to running
# 2026-07-16 11:26:09,077 INFO status has been updated to successful
# 71f03a1def3cd86937a507812d326e1.zip:   0%|          | 0.00/9.68M [00:00<?, ?B/s]
# Downloading model: gfdl_esm4
# 2026-07-16 11:26:12,981 INFO Request ID is 33177e79-39a2-40b0-90e7-8bbd5ae6f662
# 2026-07-16 11:26:13,125 INFO status has been updated to accepted
# 2026-07-16 11:26:27,972 INFO status has been updated to running
# 2026-07-16 11:27:05,916 INFO status has been updated to successful
# 99ef4b469fcffcd84115533ae19b14ee.zip:   0%|          | 0.00/19.0M [00:00<?, ?B/s]
# Downloading model: iitm_esm
# 2026-07-16 11:27:09,806 INFO Request ID is 274c9126-d83b-484e-b5fd-cee47641f31e
# 2026-07-16 11:27:09,959 INFO status has been updated to accepted
# 2026-07-16 11:27:31,422 INFO status has been updated to running
# 2026-07-16 11:28:00,241 INFO status has been updated to successful
# df44544d52ae190920865e9d72a908b8.zip:   0%|          | 0.00/9.73M [00:00<?, ?B/s]
# Downloading model: inm_cm4_8
# 2026-07-16 11:28:03,942 INFO Request ID is ffdfeafc-082e-4a96-a542-5c0c9c5819d4
# 2026-07-16 11:28:04,115 INFO status has been updated to accepted
# 2026-07-16 11:28:13,820 INFO status has been updated to running
# 2026-07-16 11:28:38,366 INFO status has been updated to successful
# 3a514cbd471cd69d1d44cdcb3a5b1331.zip:   0%|          | 0.00/7.70M [00:00<?, ?B/s]
# Downloading model: inm_cm5_0
# 2026-07-16 11:28:44,477 INFO Request ID is ed5eaf6c-82a7-4f8d-9ee9-4ca41e4b742f
# 2026-07-16 11:28:44,651 INFO status has been updated to accepted
# 2026-07-16 11:29:00,661 INFO status has been updated to running
# 2026-07-16 11:29:19,996 INFO status has been updated to successful
# 3019e004ac9526ad2dd5fac1e69eed6b.zip:   0%|          | 0.00/8.49M [00:00<?, ?B/s]
# Downloading model: ipsl_cm5a2_inca
# 2026-07-16 11:29:23,970 INFO Request ID is c5c0c2a0-33ea-40af-a7ab-548e12c3ed4f
# 2026-07-16 11:29:24,681 INFO status has been updated to accepted
# 2026-07-16 11:29:37,552 INFO status has been updated to running
# 2026-07-16 11:29:57,209 INFO status has been updated to successful
# 637a6b993572434708862885459c8a94.zip:   0%|          | 0.00/3.86M [00:00<?, ?B/s]
# Downloading model: ipsl_cm6a_lr
# 2026-07-16 11:30:01,441 INFO Request ID is 90f66cbb-9c4c-4240-a303-7ca462fd42c6
# 2026-07-16 11:30:01,589 INFO status has been updated to accepted
# 2026-07-16 11:30:22,802 INFO status has been updated to running
# 2026-07-16 11:31:17,446 INFO status has been updated to successful
# 864d2064b2b687eb1abb8c1ddf4492e6.zip:   0%|          | 0.00/8.18M [00:00<?, ?B/s]
# Downloading model: kace_1_0_g
# 2026-07-16 11:31:24,716 INFO Request ID is a5c61d68-e696-47e7-aad0-19fe732caec7
# 2026-07-16 11:31:24,871 INFO status has been updated to accepted
# 2026-07-16 11:31:48,320 INFO status has been updated to running
# 2026-07-16 11:32:17,142 INFO status has been updated to successful
# c0379da1d93f8a3bd34289f8f204cf49.zip:   0%|          | 0.00/9.50M [00:00<?, ?B/s]
# Downloading model: mcm_ua_1_0
# 2026-07-16 11:32:20,447 INFO Request ID is 3b1b5db5-9f87-4b16-9481-ddbd4e8f39bd
# 2026-07-16 11:32:21,540 INFO status has been updated to accepted
# 2026-07-16 11:32:42,106 INFO status has been updated to running
# 2026-07-16 11:32:53,734 INFO status has been updated to successful
# 28e1d88dc199bd88609f732928c664ee.zip:   0%|          | 0.00/5.88M [00:00<?, ?B/s]
# Downloading model: miroc6
# 2026-07-16 11:32:59,955 INFO Request ID is 16488935-270c-4161-ad47-d65a912030af
# 2026-07-16 11:33:00,107 INFO status has been updated to accepted
# 2026-07-16 11:33:14,446 INFO status has been updated to running
# 2026-07-16 11:33:51,049 INFO status has been updated to successful
# b36fc8ff3e713cd9ebd34f026f3b2bea.zip:   0%|          | 0.00/12.3M [00:00<?, ?B/s]
# Downloading model: miroc_es2l
# 2026-07-16 11:33:54,984 INFO Request ID is 43206a6a-00e0-4d72-b9d7-4746b4bcb65d
# 2026-07-16 11:33:55,844 INFO status has been updated to accepted
# 2026-07-16 11:34:16,891 INFO status has been updated to running
# 2026-07-16 11:34:45,714 INFO status has been updated to successful
# f5fdf709ef6c137e1e351049e2f8d336.zip:   0%|          | 0.00/3.53M [00:00<?, ?B/s]
# Downloading model: mpi_esm1_2_lr
# 2026-07-16 11:34:49,442 INFO Request ID is 6614259c-cae0-490b-b930-762f488f552b
# 2026-07-16 11:34:49,589 INFO status has been updated to accepted
# 2026-07-16 11:35:04,181 INFO status has been updated to running
# 2026-07-16 11:35:24,633 INFO status has been updated to accepted
# 2026-07-16 11:35:41,903 INFO status has been updated to successful
# 4d75e12f0b161f6853f94f735623fa62.zip:   0%|          | 0.00/6.15M [00:00<?, ?B/s]
# Downloading model: mri_esm2_0
# 2026-07-16 11:35:45,067 INFO Request ID is 262071d0-7227-4bbe-bb81-d9fa195ad8eb
# 2026-07-16 11:35:45,212 INFO status has been updated to accepted
# 2026-07-16 11:36:05,806 INFO status has been updated to running
# 2026-07-16 11:36:34,631 INFO status has been updated to successful
# dfc137c7756fbebe59d771001cb6d947.zip:   0%|          | 0.00/18.5M [00:00<?, ?B/s]
# Downloading model: noresm2_mm
# 2026-07-16 11:36:38,365 INFO Request ID is 0f447fad-19fd-4c3b-ae59-38ef58140804
# 2026-07-16 11:36:38,530 INFO status has been updated to accepted
# 2026-07-16 11:36:51,438 INFO status has been updated to running
# 2026-07-16 11:37:10,834 INFO status has been updated to successful
# 405962286b839224d6a0dfe0ee595357.zip:   0%|          | 0.00/20.8M [00:00<?, ?B/s]
# Downloading model: taiesm1
# 2026-07-16 11:37:15,015 INFO Request ID is f01a20c0-2688-48f9-84f3-d6742cd7ad6b
# 2026-07-16 11:37:15,188 INFO status has been updated to accepted
# 2026-07-16 11:37:28,052 INFO status has been updated to running
# 2026-07-16 11:37:47,387 INFO status has been updated to successful
# 33d3818e48d28f6ae01f0509a2b79ed6.zip:   0%|          | 0.00/20.6M [00:00<?, ?B/s]
# Downloading model: ukesm1_0_ll
# 2026-07-16 11:37:52,243 INFO Request ID is 0e9e5c09-b0cf-4375-9a2e-c6bc54a1189e
# 2026-07-16 11:37:53,948 INFO status has been updated to accepted
# 2026-07-16 11:38:14,516 INFO status has been updated to running
# 2026-07-16 11:38:26,070 INFO status has been updated to successful
# 8f41fb8435eca86fce83decce7f6180a.zip:   0%|          | 0.00/9.49M [00:00<?, ?B/s]
# All downloads submitted.
