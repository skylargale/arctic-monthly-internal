# %%
import cdsapi

dataset = "reanalysis-era5-pressure-levels-monthly-means"
request = {
    "product_type": ["monthly_averaged_reanalysis"],
    "variable": ["temperature"],
    "pressure_level": [
        "1", "2", "3",
        "5", "7", "10",
        "20", "30", "50",
        "70", "100", "125",
        "150", "175", "200",
        "225", "250", "300",
        "350", "400", "450",
        "500", "550", "600",
        "650", "700", "750",
        "775", "800", "825",
        "850", "875", "900",
        "925", "950", "975",
        "1000"
    ],
    "year": [
        "1980", "1981", "1982",
        "1983", "1984", "1985",
        "1986", "1987", "1988",
        "1989", "1990", "1991",
        "1992", "1993", "1994",
        "1995", "1996", "1997",
        "1998", "1999", "2000",
        "2001", "2002", "2003",
        "2004", "2005", "2006",
        "2007", "2008", "2009",
        "2010", "2011", "2012",
        "2013", "2014", "2015",
        "2016", "2017", "2018",
        "2019", "2020", "2021",
        "2022"
    ],
    "month": ["03", "04", "05"],
    "time": ["00:00"],
    "data_format": "netcdf",
    "download_format": "zip",
    "area": [90, -180, 60, 180]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2026-01-29 18:55:27,175 INFO Request ID is 0b29e9d6-9688-4681-9ef5-12b4227fe1d5
# 2026-01-29 18:55:27,407 INFO status has been updated to accepted
# 2026-01-29 18:59:48,332 INFO status has been updated to running
# 2026-01-29 19:13:52,183 INFO status has been updated to successful
# 6fbe1aa6e8b83e24c46f3a65e35f5c22.zip:   0%|          | 0.00/800M [00:00<?, ?B/s]
# '6fbe1aa6e8b83e24c46f3a65e35f5c22.zip'
