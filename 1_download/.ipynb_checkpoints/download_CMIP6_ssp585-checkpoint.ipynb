# %%
import os
import cdsapi

# %%
dataset = "projections-cmip6"

output_dir = "/glade/derecho/scratch/skygale/tmp/ssp585/"
os.makedirs(output_dir, exist_ok=True)

models = [
    "access_cm2",
    "awi_cm_1_1_mr",
    "canesm5_canoe",
    "cesm2",
    "ciesm",
    "cmcc_cm2_sr5",
    "cmcc_esm2",
    "cnrm_cm6_1",
    "cnrm_cm6_1_hr",
    "cnrm_esm2_1",
    "ec_earth3_veg_lr",
    "fgoals_f3_l",
    "fgoals_g3",
    "fio_esm_2_0",
    "gfdl_esm4",
    "hadgem3_gc31_ll",
    "hadgem3_gc31_mm",
    "iitm_esm",
    "inm_cm4_8",
    "inm_cm5_0",
    "ipsl_cm6a_lr",
    "kiost_esm",
    "mcm_ua_1_0",
    "miroc6",
    "miroc_es2l",
    "mpi_esm1_2_lr",
    "nesm3",
    "noresm2_lm",
    "taiesm1",
    "ukesm1_0_ll"
]

years = [str(y) for y in range(2015, 2023)]

base_request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp5_8_5",
    "variable": "air_temperature",
    "level": [
        "1", "5", "10", "20", "30", "50", "70", "100",
        "150", "200", "250", "300", "400", "500", "600",
        "700", "850", "925", "1000"
    ],
    "year": years,
    "month": ["03", "04", "05"],
    "area": [90, -180, 20, 180]
}

client = cdsapi.Client()

for model in models:
    print(f"Downloading model: {model}")
    outfile = os.path.join(
        output_dir,
        f"{model}_2015_2022.zip"
    )

    request = base_request.copy()
    request["model"] = model

    client.retrieve(dataset, request).download(outfile)

print("All downloads submitted.")
# Out:
# Downloading model: noresm2_lm
# 2026-07-02 19:32:29,073 INFO Request ID is ce6bc8ac-b7a6-4240-8e5f-cb9dcecedeb9
# 2026-07-02 19:32:29,274 INFO status has been updated to accepted
# 2026-07-02 19:32:50,096 INFO status has been updated to successful
# 4c63e4a0032020dc15b4f9cefbb4c57f.zip:   0%|          | 0.00/7.55M [00:00<?, ?B/s]
# Downloading model: taiesm1
# 2026-07-02 19:32:54,181 INFO Request ID is 2b7fccfb-10a4-4b68-a682-ee2b1340945f
# 2026-07-02 19:32:54,403 INFO status has been updated to accepted
# 2026-07-02 19:33:09,387 INFO status has been updated to running
# 2026-07-02 19:33:46,084 INFO status has been updated to successful
# 5c946bd9daca75ec5077a3434f62c98b.zip:   0%|          | 0.00/28.3M [00:00<?, ?B/s]
# Downloading model: ukesm1_0_ll
# 2026-07-02 19:33:52,490 INFO Request ID is 124466f7-3a2a-49e7-8b07-395f479f2b3d
# 2026-07-02 19:33:52,688 INFO status has been updated to accepted
# 2026-07-02 19:34:05,649 INFO status has been updated to running
# 2026-07-02 19:34:25,049 INFO status has been updated to successful
# c910ef5fcfac9780f57456db2171a1d6.zip:   0%|          | 0.00/10.7M [00:00<?, ?B/s]
# All downloads submitted.
